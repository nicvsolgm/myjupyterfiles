# %%
import pandas as pd
from matplotlib import pyplot as plt
pd.set_option('display.max_rows', 200)

# %%
nba = pd.read_csv('nba.csv')

# %%
nba.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.set_index('Name').head()
# Out:
#                          Team  Number Position  Age  Height  Weight  \
# Name
# Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# Jae Crowder    Boston Celtics      99       SF   25   6-Jun     235
# John Holland   Boston Celtics      30       SG   27   5-Jun     205
# R.J. Hunter    Boston Celtics      28       SG   22   5-Jun     185
# Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0

# %%
nba.set_index(['Name','Team']).head()
# Out:
#                               Number Position  Age  Height  Weight  \
# Name          Team
# Avery Bradley Boston Celtics       0       PG   25   2-Jun     180
# Jae Crowder   Boston Celtics      99       SF   25   6-Jun     235
# John Holland  Boston Celtics      30       SG   27   5-Jun     205
# R.J. Hunter   Boston Celtics      28       SG   22   5-Jun     185
# Jonas Jerebko Boston Celtics       8       PF   29  10-Jun     231
#
#                                         College     Salary
# Name          Team
# Avery Bradley Boston Celtics              Texas  7730337.0
# Jae Crowder   Boston Celtics          Marquette  6796117.0
# John Holland  Boston Celtics  Boston University        NaN
# R.J. Hunter   Boston Celtics      Georgia State  1148640.0
# Jonas Jerebko Boston Celtics                NaN  5000000.0

# %%
nba.Name.iloc[400,]
# Out:
# 'Kevin Garnett'

# %%
nba.Name.loc[ : ]
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 452       Trey Lyles
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# Name: Name, Length: 457, dtype: object

# %%
nba.Name.loc[0:5]
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# 5     Amir Johnson
# Name: Name, dtype: object

# %%
nba.Name
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 452       Trey Lyles
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# Name: Name, Length: 457, dtype: object

# %%
boston = nba[nba.Team == "Boston Celtics"]

# %%
boston
# Out:
#                Name            Team  Number Position  Age  Height  Weight  \
# 0     Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1       Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2      John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3       R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4     Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# 5      Amir Johnson  Boston Celtics      90       PF   29   9-Jun     240
# 6     Jordan Mickey  Boston Celtics      55       PF   21   8-Jun     235
# 7      Kelly Olynyk  Boston Celtics      41        C   25  Jul-00     238
# 8      Terry Rozier  Boston Celtics      12       PG   22   2-Jun     190
# 9      Marcus Smart  Boston Celtics      36       PG   22   4-Jun     220
# 10  Jared Sullinger  Boston Celtics       7        C   24   9-Jun     260
# 11    Isaiah Thomas  Boston Celtics       4       PG   27   9-May     185
# ...

# %%
utah = nba[nba.Team == "Utah Jazz"]

# %%
utah
# Out:
#                Name       Team  Number Position  Age  Height  Weight  \
# 442   Trevor Booker  Utah Jazz      33       PF   28   8-Jun     228
# 443      Trey Burke  Utah Jazz       3       PG   23   1-Jun     191
# 444      Alec Burks  Utah Jazz      10       SG   24   6-Jun     214
# 445      Dante Exum  Utah Jazz      11       PG   20   6-Jun     190
# 446  Derrick Favors  Utah Jazz      15       PF   24  10-Jun     265
# 447     Rudy Gobert  Utah Jazz      27        C   23   1-Jul     245
# 448  Gordon Hayward  Utah Jazz      20       SF   26   8-Jun     226
# 449     Rodney Hood  Utah Jazz       5       SG   23   8-Jun     206
# 450      Joe Ingles  Utah Jazz       2       SF   28   8-Jun     226
# 451   Chris Johnson  Utah Jazz      23       SF   26   6-Jun     206
# 452      Trey Lyles  Utah Jazz      41       PF   20  10-Jun     234
# 453    Shelvin Mack  Utah Jazz       8       PG   26   3-Jun     203
# 454       Raul Neto  Utah Jazz      25       PG   24   1-Jun     179
# ...

# %%
nba2 = nba.pivot_table(index =['Team','Name','Salary','Weight','Age'], columns = 'Position')
nba2
# Out:
#                                                          Number             \
# Position                                                      C   PF    PG
# Team               Name            Salary     Weight Age
# Atlanta Hawks      Al Horford      12000000.0 245    30    15.0  NaN   NaN
#                    Dennis Schroder 1763400.0  172    22     NaN  NaN  17.0
#                    Jeff Teague     8000000.0  186    27     NaN  NaN   0.0
#                    Kent Bazemore   2000000.0  201    26     NaN  NaN   NaN
#                    Kirk Hinrich    2854940.0  190    35     NaN  NaN   NaN
# ...                                                         ...  ...   ...
# Washington Wizards Marcus Thornton 200600.0   205    29     NaN  NaN   NaN
#                    Markieff Morris 8000000.0  245    26     NaN  5.0   NaN
#                    Nene Hilario    13000000.0 250    33    42.0  NaN   NaN
#                    Otto Porter Jr. 4662960.0  198    23     NaN  NaN   NaN
# ...

# %%
nba.loc[nba.Team =='Atlanta Hawks', :]
# Out:
#                  Name           Team  Number Position  Age  Height  Weight  \
# 309     Kent Bazemore  Atlanta Hawks      24       SF   26   5-Jun     201
# 310  Tim Hardaway Jr.  Atlanta Hawks      10       SG   24   6-Jun     205
# 311      Kirk Hinrich  Atlanta Hawks      12       SG   35   4-Jun     190
# 312        Al Horford  Atlanta Hawks      15        C   30  10-Jun     245
# 313    Kris Humphries  Atlanta Hawks      43       PF   31   9-Jun     235
# 314       Kyle Korver  Atlanta Hawks      26       SG   35   7-Jun     212
# 315      Paul Millsap  Atlanta Hawks       4       PF   31   8-Jun     246
# 316      Mike Muscala  Atlanta Hawks      31       PF   24  11-Jun     240
# 317   Lamar Patterson  Atlanta Hawks      13       SG   24   5-Jun     225
# 318   Dennis Schroder  Atlanta Hawks      17       PG   22   1-Jun     172
# 319        Mike Scott  Atlanta Hawks      32       PF   27   8-Jun     237
# ...

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number        int64
# Position     object
# Age           int64
# Height       object
# Weight        int64
# College      object
# Salary      float64
# dtype: object

# %%
pd.crosstab(nba.Team,nba.Position)
# Out:
# Position                C  PF  PG  SF  SG
# Team
# Atlanta Hawks           3   4   2   2   4
# Boston Celtics          3   3   4   1   4
# Brooklyn Nets           2   4   3   0   6
# Charlotte Hornets       3   3   3   1   5
# Chicago Bulls           2   5   2   2   4
# Cleveland Cavaliers     3   2   3   2   5
# Dallas Mavericks        3   4   4   2   2
# Denver Nuggets          3   2   3   3   4
# Detroit Pistons         3   2   4   4   2
# Golden State Warriors   3   2   2   5   3
# Houston Rockets         2   4   2   3   4
# Indiana Pacers          2   4   4   3   2
# Los Angeles Clippers    2   3   3   4   3
# Los Angeles Lakers      3   4   3   4   1
# Memphis Grizzlies       1   6   5   3   3
# Miami Heat              1   4   2   5   3
# Milwaukee Bucks         2   3   4   3   4
# Minnesota Timberwolves  3   4   3   3   1
# New Orleans Pelicans    3   3   4   4   5
# New York Knicks         2   4   2   4   4
# Oklahoma City Thunder   3   3   2   3   4
# ...

# %%
pd.crosstab(nba.Team,nba.College)
# Out:
# College                 Alabama  Arizona  Arizona State  Arkansas  Baylor  \
# Team
# Atlanta Hawks                 0        0              0         0       0
# Boston Celtics                0        0              0         0       0
# Brooklyn Nets                 0        1              0         0       0
# Charlotte Hornets             0        0              0         0       0
# Chicago Bulls                 0        0              0         1       0
# Cleveland Cavaliers           1        2              0         0       0
# Dallas Mavericks              0        0              0         0       0
# Denver Nuggets                0        0              0         0       0
# Detroit Pistons               0        1              0         0       0
# Golden State Warriors         0        1              0         0       0
# Houston Rockets               0        1              1         1       0
# Indiana Pacers                0        2              0         0       0
# ...

# %%
nba.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df
