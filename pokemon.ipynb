# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('pokemon_data2.csv')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.index
# Out:
# RangeIndex(start=0, stop=800, step=1)

# %%
df2=[column for column in df if column!= '#']
df3=df[df2]
df3
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass  Poison  45      49       49       65
# 1                  Ivysaur    Grass  Poison  60      62       63       80
# 2                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 795                Diancie     Rock   Fairy  50     100      150      100
# 796    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 799              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df4=[column for column in df if column!="Defense"]
df5=df[df4]
df5
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Sp. Atk  \
# 0      1              Bulbasaur    Grass  Poison  45      49       65
# 1      2                Ivysaur    Grass  Poison  60      62       80
# 2      3               Venusaur    Grass  Poison  80      82      100
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      122
# 4      4             Charmander     Fire     NaN  39      52       60
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      100
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      160
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110      150
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160      170
# 799  721              Volcanion     Fire   Water  80     110      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df6=df.columns
df6
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
keep=['Generation','HP', 'Attack', 'Defense']
grpdf=df[keep]
grpdf
# Out:
#      Generation  HP  Attack  Defense
# 0             1  45      49       49
# 1             1  60      62       63
# 2             1  80      82       83
# 3             1  80     100      123
# 4             1  39      52       43
# ..          ...  ..     ...      ...
# 795           6  50     100      150
# 796           6  50     160      110
# 797           6  80     110       60
# 798           6  80     160       60
# 799           6  80     110      120
#
# [800 rows x 4 columns]

# %%
grpdf2=grpdf.groupby("Generation")
grpdf2

# %%
for groupgen,groupatt in grpdf2:
    #print(groupgen)
    print(groupatt)
# Out:
#      Generation   HP  Attack  Defense
# 0             1   45      49       49
# 1             1   60      62       63
# 2             1   80      82       83
# 3             1   80     100      123
# 4             1   39      52       43
# ..          ...  ...     ...      ...
# 161           1   91     134       95
# 162           1  106     110       90
# 163           1  106     190      100
# 164           1  106     150       70
# 165           1  100     100      100
#
# [166 rows x 4 columns]
#      Generation   HP  Attack  Defense
# 166           2   45      49       65
# 167           2   60      62       80
# 168           2   80      82      100
# 169           2   39      52       43
# 170           2   58      64       58
# ..          ...  ...     ...      ...
# 267           2  100     134      110
# 268           2  100     164      150
# 269           2  106      90      130
# 270           2  106     130       90
# 271           2  100     100      100
#
# ...

# %%
g1=grpdf2.get_group(1)
g1
# Out:
#      Generation   HP  Attack  Defense
# 0             1   45      49       49
# 1             1   60      62       63
# 2             1   80      82       83
# 3             1   80     100      123
# 4             1   39      52       43
# ..          ...  ...     ...      ...
# 161           1   91     134       95
# 162           1  106     110       90
# 163           1  106     190      100
# 164           1  106     150       70
# 165           1  100     100      100
#
# [166 rows x 4 columns]

# %%
g2=grpdf2.get_group(2)
g2
# Out:
#      Generation   HP  Attack  Defense
# 166           2   45      49       65
# 167           2   60      62       80
# 168           2   80      82      100
# 169           2   39      52       43
# 170           2   58      64       58
# ..          ...  ...     ...      ...
# 267           2  100     134      110
# 268           2  100     164      150
# 269           2  106      90      130
# 270           2  106     130       90
# 271           2  100     100      100
#
# [106 rows x 4 columns]

# %%
grpdf2.get_group(1).std()
# Out:
# Generation     0.000000
# HP            28.153968
# Attack        30.744727
# Defense       28.641336
# dtype: float64

# %%
grpdf2=grpdf.groupby("Generation").std()
grpdf2
# Out:
#                    HP     Attack    Defense
# Generation
# 1           28.153968  30.744727  28.641336
# 2           30.589359  32.708658  39.233749
# 3           24.059634  36.593767  35.222599
# 4           25.113604  32.780569  30.145741
# 5           22.407748  30.365685  23.318883
# 6           20.907822  29.179495  31.370301

# %%
grpdf2["Generation"].value_counts()
# Out:
# Generation  Generation
# 1           1             166
# 2           2             106
# 3           3             160
# 4           4             121
# 5           5             165
# 6           6              82
# Name: Generation, dtype: int64

# %%
grpdf2=grpdf.groupby("Generation").std().plot()
plt.title("Standard Deviation by Generation")
plt.grid()

# %%
grpdf3=grpdf.groupby("Generation").mean().plot()
plt.title("Average by Generation")
plt.show()

# %%
df.set_index("Name").head(|)
# Out:
#                        # Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              1  Grass  Poison  45      49       49       65
# Ivysaur                2  Grass  Poison  60      62       63       80
# Venusaur               3  Grass  Poison  80      82       83      100
# VenusaurMega Venusaur  3  Grass  Poison  80     100      123      122
# Charmander             4   Fire     NaN  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur                   65     45           1      False
# Ivysaur                     80     60           1      False
# Venusaur                   100     80           1      False
# VenusaurMega Venusaur      120     80           1      False
# Charmander                  50     65           1      False

# %%
df.set_index(["#"]).head(10)
# Out:
#                         Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1                  Bulbasaur  Grass  Poison  45      49       49       65
# 2                    Ivysaur  Grass  Poison  60      62       63       80
# 3                   Venusaur  Grass  Poison  80      82       83      100
# 3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4                 Charmander   Fire     NaN  39      52       43       60
# 5                 Charmeleon   Fire     NaN  58      64       58       80
# 6                  Charizard   Fire  Flying  78      84       78      109
# 6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# ...

# %%
groupdf=df3.groupby(["Generation","Legendary"])
groupdf

# %%
groupdf=df3.groupby(["Generation","Legendary"]).mean()
groupdf
# Out:
#                               HP      Attack     Defense     Sp. Atk  \
# Generation Legendary
# 1          False       64.612500   74.981250   70.175000   69.218750
#            True        98.000000  120.833333   89.166667  141.166667
# 2          False       69.613861   70.693069   72.118812   64.306931
#            True       103.400000   99.000000   99.000000   99.000000
# 3          False       64.626761   76.971831   69.901408   69.429577
#            True        81.666667  118.333333  107.222222  126.111111
# 4          False       69.740741   79.620370   75.074074   71.620370
#            True       100.846154  109.846154  103.538462  116.153846
# 5          False       69.353333   78.246667   70.486667   67.406667
#            True        96.133333  120.266667   90.733333  117.800000
# 6          False       66.189189   70.459459   74.013514   68.094595
#            True        87.500000  125.250000  101.375000  131.625000
#
#                          Sp. Def       Speed
# ...

# %%
groupdf2=df3.groupby(["Legendary","Generation"]).std()
groupdf2
# Out:
#                              HP     Attack    Defense    Sp. Atk    Sp. Def  \
# Legendary Generation
# False     1           27.921270  29.180090  28.883533  31.720809  24.990092
#           2           30.409199  32.626291  39.511084  27.364482  29.781734
#           3           23.908991  33.367488  32.007160  29.274295  24.588131
#           4           22.925059  32.486293  29.941908  29.409680  26.809812
#           5           21.467358  28.383504  23.062721  28.753546  21.635509
#           6           18.786235  24.290586  30.437672  25.250075  28.050676
# True      1            8.763561  41.038600  11.143010  33.984801  16.931233
#           2            9.208692  22.748626  22.748626  12.449900  34.500725
#           3           20.000000  41.016496  42.399439  39.983657  42.721931
#           4           26.175199  21.259689  17.614461  23.465742  17.614461
#           5           16.689889  22.527655  17.600595  25.293139  15.768262
# ...

# %%
grpnm=df3.groupby("Name")
grpnm

# %%
grpnm.get_group("Bulbasaur")
# Out:
#         Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  Bulbasaur  Grass  Poison  45      49       49       65       65     45
#
#    Generation  Legendary
# 0           1      False

# %%
df3.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison  45      49       49       65
# 1                Ivysaur  Grass  Poison  60      62       63       80
# 2               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df3.pivot(index="Name",columns="Legendary",values="Legendary")
# Out:
# Generation                   1    2      3      4      5     6
# Name
# Abomasnow                  NaN  NaN    NaN  False    NaN   NaN
# AbomasnowMega Abomasnow    NaN  NaN    NaN  False    NaN   NaN
# Abra                     False  NaN    NaN    NaN    NaN   NaN
# Absol                      NaN  NaN  False    NaN    NaN   NaN
# AbsolMega Absol            NaN  NaN  False    NaN    NaN   NaN
# ...                        ...  ...    ...    ...    ...   ...
# Zoroark                    NaN  NaN    NaN    NaN  False   NaN
# Zorua                      NaN  NaN    NaN    NaN  False   NaN
# Zubat                    False  NaN    NaN    NaN    NaN   NaN
# Zweilous                   NaN  NaN    NaN    NaN  False   NaN
# Zygarde50% Forme           NaN  NaN    NaN    NaN    NaN  True
#
# [800 rows x 6 columns]

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
gragg=groupdf.agg({ "Attack":   ["mean", "min","std"],"Defense":
["mean","min","std"]})

# %%
gragg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-460b98002a8e> in <module>()
# ----> 1 gragg
#
# NameError: name 'gragg' is not defined

# %%
groupdf.describe()
# Out:
#                HP      Attack     Defense     Sp. Atk     Sp. Def       Speed
# count   12.000000   12.000000   12.000000   12.000000   12.000000   12.000000
# mean    80.973545   95.375178   85.233763   95.161126   88.329241   82.602720
# std     15.387087   22.230260   14.754832   29.720135   20.977815   19.467339
# min     64.612500   70.459459   69.901408   64.306931   65.816901   59.920792
# 25%     68.562297   76.474186   71.710776   68.937711   70.075296   64.671757
# 50%     75.703704   89.310185   82.120370   85.310185   83.042593   77.606250
# 75%     96.600000  118.816667   99.593750  119.877778  105.810096  100.935897
# max    103.400000  125.250000  107.222222  141.166667  119.600000  112.500000

# %%
df.set_index(["#","Name"]).head(2)
# Out:
#             Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# # Name
# 1 Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2 Ivysaur    Grass  Poison  60      62       63       80       80     60
#
#              Generation  Legendary
# # Name
# 1 Bulbasaur           1      False
# 2 Ivysaur             1      False

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.iat[2,2]
# Out:
# 'Grass'

# %%
df.iat[2,4]
# Out:
# 80

# %%
df.iat[4,2]
# Out:
# 'Fire'

# %%
df.at[3,"Attack"]
# Out:
# 100

# %%
df.at[5,"Attack"]
# Out:
# 64

# %%
sub5 = df[::5]

# %%
sub5.head(2)
# Out:
#    #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1   Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 5  5  Charmeleon   Fire     NaN  58      64       58       80       65     80
#
#    Generation  Legendary
# 0           1      False
# 5           1      False

# %%
df[::7].head(2)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 7       85    100           1      False

# %%
fillna= df.fillna(0)

# %%
fillna.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire       0  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
fillna= df.fillna('not applicable')

# %%
fillna.head()
# Out:
#    #                   Name Type 1          Type 2  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass          Poison  45      49       49
# 1  2                Ivysaur  Grass          Poison  60      62       63
# 2  3               Venusaur  Grass          Poison  80      82       83
# 3  3  VenusaurMega Venusaur  Grass          Poison  80     100      123
# 4  4             Charmander   Fire  not applicable  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
dropn1=df.dropna(how="all")
dropn1
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
dropna.dropna(thresh=1)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
fillna.head()
# Out:
#    #                   Name Type 1          Type 2  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass          Poison  45      49       49
# 1  2                Ivysaur  Grass          Poison  60      62       63
# 2  3               Venusaur  Grass          Poison  80      82       83
# 3  3  VenusaurMega Venusaur  Grass          Poison  80     100      123
# 4  4             Charmander   Fire  not applicable  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
fillna2=df.fillna({
        "Type 2": "unknown"
    })

# %%
fillna2.head(10)
# Out:
#    #                       Name Type 1   Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass   Poison  45      49       49       65
# 1  2                    Ivysaur  Grass   Poison  60      62       63       80
# 2  3                   Venusaur  Grass   Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass   Poison  80     100      123      122
# 4  4                 Charmander   Fire  unknown  39      52       43       60
# 5  5                 Charmeleon   Fire  unknown  58      64       58       80
# 6  6                  Charizard   Fire   Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire   Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire   Flying  78     104       78      159
# 9  7                   Squirtle  Water  unknown  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
df.Speed.mean()
# Out:
# 68.2775

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.drop("Legendary", axis=1 ).head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation
# 0       65     45           1
# 1       80     60           1
# 2      100     80           1
# 3      120     80           1
# 4       50     65           1

# %%
df.drop(["Attack","Defense"], axis=1 ).head()
# Out:
#    #                   Name Type 1  Type 2  HP  Sp. Atk  Sp. Def  Speed  \
# 0  1              Bulbasaur  Grass  Poison  45       65       65     45
# 1  2                Ivysaur  Grass  Poison  60       80       80     60
# 2  3               Venusaur  Grass  Poison  80      100      100     80
# 3  3  VenusaurMega Venusaur  Grass  Poison  80      122      120     80
# 4  4             Charmander   Fire     NaN  39       60       50     65
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False

# %%
dfn=df.drop(["Attack","Defense"], axis=1 ).head()
dfn
# Out:
#    #                   Name Type 1  Type 2  HP  Sp. Atk  Sp. Def  Speed  \
# 0  1              Bulbasaur  Grass  Poison  45       65       65     45
# 1  2                Ivysaur  Grass  Poison  60       80       80     60
# 2  3               Venusaur  Grass  Poison  80      100      100     80
# 3  3  VenusaurMega Venusaur  Grass  Poison  80      122      120     80
# 4  4             Charmander   Fire     NaN  39       60       50     65
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.drop([2,4],axis=0).head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
# 6  6              Charizard   Fire  Flying  78      84       78      109
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 3      120     80           1      False
# 5       65     80           1      False
# 6       85    100           1      False

# %%
df.mean()
# Out:
# #             362.81375
# HP             69.25875
# Attack         79.00125
# Defense        73.84250
# Sp. Atk        72.82000
# Sp. Def        71.90250
# Speed          68.27750
# Generation      3.32375
# Legendary       0.08125
# dtype: float64

# %%
df.mean(axis =0)
# Out:
# #             362.81375
# HP             69.25875
# Attack         79.00125
# Defense        73.84250
# Sp. Atk        72.82000
# Sp. Def        71.90250
# Speed          68.27750
# Generation      3.32375
# Legendary       0.08125
# dtype: float64

# %%
df.mean(axis =1).head(3)
# Out:
# 0    35.555556
# 1    45.333333
# 2    58.777778
# dtype: float64

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.Attack.mean()
# Out:
# 79.00125

# %%
df.HP.mean()
# Out:
# 69.25875

# %%
df.rename(columns = {"Type 1":"Type_1","Type 2" : "Type_2"},inplace = True)
df.head()
# Out:
#    #                   Name Type_1  Type_2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.head()
# Out:
#    #                   Name Type_1  Type_2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.iloc[2]
# Out:
# #                    3
# Name          Venusaur
# Type_1           Grass
# Type_2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object

# %%
df.columns = df.columns.str.replace( " ", "_")

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type_1', 'Type_2', 'HP', 'Attack', 'Defense', 'Sp._Atk',
#        'Sp._Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.iloc[2: ].head()
# Out:
#    #                   Name Type_1  Type_2  HP  Attack  Defense  Sp._Atk  \
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
# 6  6              Charizard   Fire  Flying  78      84       78      109
#
#    Sp._Def  Speed  Generation  Legendary
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False

# %%
df.loc[:].tail()
# Out:
#        #                 Name   Type_1 Type_2  HP  Attack  Defense  Sp._Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp._Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.loc[:9]
# Out:
#    #                       Name Type_1  Type_2  HP  Attack  Defense  Sp._Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp._Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
df.loc[0, :]
# Out:
# #                     1
# Name          Bulbasaur
# Type_1            Grass
# Type_2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp._Atk              65
# Sp._Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
df.loc[0:2, :]
# Out:
#    #       Name Type_1  Type_2  HP  Attack  Defense  Sp._Atk  Sp._Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
df.loc[0:2, "Name"]
# Out:
# 0    Bulbasaur
# 1      Ivysaur
# 2     Venusaur
# Name: Name, dtype: object

# %%
df.count().head()
# Out:
# #         800
# Name      800
# Type_1    800
# Type_2    414
# HP        800
# dtype: int64

# %%
df.loc[0:2, ["Name", "Type_1"]]
# Out:
#         Name Type_1
# 0  Bulbasaur  Grass
# 1    Ivysaur  Grass
# 2   Venusaur  Grass

# %%
df.loc[:,'Type_2']
# Out:
# 0      Poison
# 1      Poison
# 2      Poison
# 3      Poison
# 4         NaN
#         ...
# 795     Fairy
# 796     Fairy
# 797     Ghost
# 798      Dark
# 799     Water
# Name: Type_2, Length: 800, dtype: object

# %%
df.loc[0:2, "Name": "Generation"]
# Out:
#         Name Type_1  Type_2  HP  Attack  Defense  Sp._Atk  Sp._Def  Speed  \
# 0  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation
# 0           1
# 1           1
# 2           1

# %%
df.loc[df.Name =="Bulbasaur", :]
# Out:
#    #       Name Type_1  Type_2  HP  Attack  Defense  Sp._Atk  Sp._Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
#
#    Generation  Legendary
# 0           1      False

# %%
df.loc[df.HP <=60, :]
# Out:
#        #                 Name  Type_1  Type_2  HP  Attack  Defense  Sp._Atk  \
# 0      1            Bulbasaur   Grass  Poison  45      49       49       65
# 1      2              Ivysaur   Grass  Poison  60      62       63       80
# 4      4           Charmander    Fire     NaN  39      52       43       60
# 5      5           Charmeleon    Fire     NaN  58      64       58       80
# 9      7             Squirtle   Water     NaN  44      48       65       50
# ..   ...                  ...     ...     ...  ..     ...      ...      ...
# 785  711  GourgeistSmall Size   Ghost   Grass  55      85      122       58
# 788  712             Bergmite     Ice     NaN  55      69       85       32
# 790  714               Noibat  Flying  Dragon  40      30       35       45
# 795  719              Diancie    Rock   Fairy  50     100      150      100
# 796  719  DiancieMega Diancie    Rock   Fairy  50     160      110      160
#
#      Sp._Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df.Type_1 =="Grass", :].head()
# Out:
#      #                   Name Type_1  Type_2  HP  Attack  Defense  Sp._Atk  \
# 0    1              Bulbasaur  Grass  Poison  45      49       49       65
# 1    2                Ivysaur  Grass  Poison  60      62       63       80
# 2    3               Venusaur  Grass  Poison  80      82       83      100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 48  43                 Oddish  Grass  Poison  45      50       55       75
#
#     Sp._Def  Speed  Generation  Legendary
# 0        65     45           1      False
# 1        80     60           1      False
# 2       100     80           1      False
# 3       120     80           1      False
# 48       65     30           1      False

# %%
df.loc[[1,2]]
# Out:
#    #      Name Type_1  Type_2  HP  Attack  Defense  Sp._Atk  Sp._Def  Speed  \
# 1  2   Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3  Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 1           1      False
# 2           1      False

# %%
df.loc[[0,4]]
# Out:
#    #        Name Type_1  Type_2  HP  Attack  Defense  Sp._Atk  Sp._Def  Speed  \
# 0  1   Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 4  4  Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary
# 0           1      False
# 4           1      False

# %%
df.loc[2:,"Type_1"]
# Out:
# 2        Grass
# 3        Grass
# 4         Fire
# 5         Fire
# 6         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Type_1, Length: 798, dtype: object

# %%
df.loc[[1,4]]
# Out:
#    #        Name Type_1  Type_2  HP  Attack  Defense  Sp._Atk  Sp._Def  Speed  \
# 1  2     Ivysaur  Grass  Poison  60      62       63       80       80     60
# 4  4  Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary
# 1           1      False
# 4           1      False

# %%
df.loc[[1,2,6]]
# Out:
#    #       Name Type_1  Type_2  HP  Attack  Defense  Sp._Atk  Sp._Def  Speed  \
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
# 6  6  Charizard   Fire  Flying  78      84       78      109       85    100
#
#    Generation  Legendary
# 1           1      False
# 2           1      False
# 6           1      False

# %%
df.loc[:,'Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df.loc[:,'Name':'Speed'].head(2)
# Out:
#         Name Type_1  Type_2  HP  Attack  Defense  Sp._Atk  Sp._Def  Speed
# 0  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1    Ivysaur  Grass  Poison  60      62       63       80       80     60

# %%
df.loc[:,('Name','Speed')].head(2)
# Out:
#         Name  Speed
# 0  Bulbasaur     45
# 1    Ivysaur     60

# %%
df.iloc[2,2]
# Out:
# 'Grass'

# %%
df.Name.iloc[2]
# Out:
# 'Venusaur'

# %%
df.Name.iloc[2:4]
# Out:
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# Name: Name, dtype: object

# %%
df[['Name','Legendary']].iloc[2:4]
# Out:
#                     Name  Legendary
# 2               Venusaur      False
# 3  VenusaurMega Venusaur      False

# %%
grass =[df.Name == "Bulbasaur"]

# %%
grass
# Out:
#    #       Name Type_1  Type_2  HP  Attack  Defense  Sp._Atk  Sp._Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
#
#    Generation  Legendary
# 0           1      False

# %%
grass2 = df[df.Type_2 == "Poison"].Name

# %%
grass2.head(2)
# Out:
# 0    Bulbasaur
# 1      Ivysaur
# Name: Name, dtype: object

# %%
df.head()
# Out:
#    #                   Name Type_1  Type_2  HP  Attack  Defense  Sp._Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp._Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.set_index("Name")
# Out:
#                          #   Type_1  Type_2  HP  Attack  Defense  Sp._Atk  \
# Name
# Bulbasaur                1    Grass  Poison  45      49       49       65
# Ivysaur                  2    Grass  Poison  60      62       63       80
# Venusaur                 3    Grass  Poison  80      82       83      100
# VenusaurMega Venusaur    3    Grass  Poison  80     100      123      122
# Charmander               4     Fire     NaN  39      52       43       60
# ...                    ...      ...     ...  ..     ...      ...      ...
# Diancie                719     Rock   Fairy  50     100      150      100
# DiancieMega Diancie    719     Rock   Fairy  50     160      110      160
# HoopaHoopa Confined    720  Psychic   Ghost  80     110       60      150
# HoopaHoopa Unbound     720  Psychic    Dark  80     160       60      170
# Volcanion              721     Fire   Water  80     110      120      130
#
#                        Sp._Def  Speed  Generation  Legendary
# Name
# ...

# %%
gras= df[(df.HP >= 45)&(df.Attack>=60)]

# %%
gras.head()
# Out:
#    #                   Name Type_1  Type_2  HP  Attack  Defense  Sp._Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
# 6  6              Charizard   Fire  Flying  78      84       78      109
#
#    Sp._Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 5       65     80           1      False
# 6       85    100           1      False

# %%
gras3 = df[(df.HP >= 45)&(df.Defense>=60)].Name

# %%
gras3.head()
# Out:
# 1                      Ivysaur
# 2                     Venusaur
# 3        VenusaurMega Venusaur
# 6                    Charizard
# 7    CharizardMega Charizard X
# Name: Name, dtype: object

# %%
gras4 = df[(df.HP >= 45)&(df.Defense>=60)]['Name']
gras4
# Out:
# 1                        Ivysaur
# 2                       Venusaur
# 3          VenusaurMega Venusaur
# 6                      Charizard
# 7      CharizardMega Charizard X
#                  ...
# 795                      Diancie
# 796          DiancieMega Diancie
# 797          HoopaHoopa Confined
# 798           HoopaHoopa Unbound
# 799                    Volcanion
# Name: Name, Length: 503, dtype: object

# %%
gras4 = df[(df.HP >= 45)&(df.Defense>=60)][['Name','Speed']]
gras4
# Out:
#                           Name  Speed
# 1                      Ivysaur     60
# 2                     Venusaur     80
# 3        VenusaurMega Venusaur     80
# 6                    Charizard    100
# 7    CharizardMega Charizard X    100
# ..                         ...    ...
# 795                    Diancie     50
# 796        DiancieMega Diancie    110
# 797        HoopaHoopa Confined     70
# 798         HoopaHoopa Unbound     80
# 799                  Volcanion     70
#
# [503 rows x 2 columns]

# %%
grass2 = df[df.HP== 60]

# %%
grass2.head()
# Out:
#      #        Name    Type_1  Type_2  HP  Attack  Defense  Sp._Atk  Sp._Def  \
# 1    2     Ivysaur     Grass  Poison  60      62       63       80       80
# 15  12  Butterfree       Bug  Flying  60      45       50       90       80
# 29  24       Arbok    Poison     NaN  60      85       69       65       79
# 31  26      Raichu  Electric     NaN  60      90       55       90       80
# 49  44       Gloom     Grass  Poison  60      65       70       85       75
#
#     Speed  Generation  Legendary
# 1      60           1      False
# 15     70           1      False
# 29     80           1      False
# 31    110           1      False
# 49     40           1      False

# %%
is_long = df.Attack >= 60

# %%
is_long3= df[['Name','Generation']][df['HP']>= 60]

# %%
is_long3
# Out:
#                           Name  Generation
# 1                      Ivysaur           1
# 2                     Venusaur           1
# 3        VenusaurMega Venusaur           1
# 6                    Charizard           1
# 7    CharizardMega Charizard X           1
# ..                         ...         ...
# 793                    Yveltal           6
# 794           Zygarde50% Forme           6
# 797        HoopaHoopa Confined           6
# 798         HoopaHoopa Unbound           6
# 799                  Volcanion           6
#
# [528 rows x 2 columns]

# %%
df[df.Defense >=60]
# Out:
#        #                       Name   Type_1  Type_2  HP  Attack  Defense  \
# 1      2                    Ivysaur    Grass  Poison  60      62       63
# 2      3                   Venusaur    Grass  Poison  80      82       83
# 3      3      VenusaurMega Venusaur    Grass  Poison  80     100      123
# 6      6                  Charizard     Fire  Flying  78      84       78
# 7      6  CharizardMega Charizard X     Fire  Dragon  78     130      111
# ..   ...                        ...      ...     ...  ..     ...      ...
# 795  719                    Diancie     Rock   Fairy  50     100      150
# 796  719        DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720        HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720         HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721                  Volcanion     Fire   Water  80     110      120
#
#      Sp._Atk  Sp._Def  Speed  Generation  Legendary
# ...

# %%
df[df.Defense>=65].Name
# Out:
# 2                       Venusaur
# 3          VenusaurMega Venusaur
# 6                      Charizard
# 7      CharizardMega Charizard X
# 8      CharizardMega Charizard Y
#                  ...
# 793                      Yveltal
# 794             Zygarde50% Forme
# 795                      Diancie
# 796          DiancieMega Diancie
# 799                    Volcanion
# Name: Name, Length: 467, dtype: object

# %%
df.loc[df.Attack >=95, ["Name","Attack"]].head()
# Out:
#                          Name  Attack
# 3       VenusaurMega Venusaur     100
# 7   CharizardMega Charizard X     130
# 8   CharizardMega Charizard Y     104
# 12    BlastoiseMega Blastoise     103
# 19      BeedrillMega Beedrill     150

# %%
df.reindex()
# Out:
#        #                   Name   Type_1  Type_2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp._Atk  Sp._Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df
# Out:
#        #                   Name   Type_1  Type_2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp._Atk  Sp._Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.loc[df.HP >=55, ["Name","Legendary"]]
# Out:
#                       Name  Legendary
# 1                  Ivysaur      False
# 2                 Venusaur      False
# 3    VenusaurMega Venusaur      False
# 5               Charmeleon      False
# 6                Charizard      False
# ..                     ...        ...
# 793                Yveltal       True
# 794       Zygarde50% Forme       True
# 797    HoopaHoopa Confined       True
# 798     HoopaHoopa Unbound       True
# 799              Volcanion       True
#
# [580 rows x 2 columns]

# %%
df.loc[(df.HP >=65)&(df.Attack>=90),["Name","Attack","Legendary","Speed"]].head()
# Out:
#                          Name  Attack  Legendary  Speed
# 3       VenusaurMega Venusaur     100      False     80
# 7   CharizardMega Charizard X     130      False    100
# 8   CharizardMega Charizard Y     104      False    100
# 12    BlastoiseMega Blastoise     103      False     78
# 18                   Beedrill      90      False     75

# %%
df
# Out:
#        #                   Name   Type_1  Type_2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp._Atk  Sp._Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.reindex()
# Out:
#        #                   Name   Type_1  Type_2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp._Atk  Sp._Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.head()
# Out:
#    #                   Name Type_1  Type_2  HP  Attack  Defense  Sp._Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp._Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.drop("#", axis = 1, inplace=True)

# %%
df
# Out:
#                       Name   Type_1  Type_2  HP  Attack  Defense  Sp._Atk  \
# 0                Bulbasaur    Grass  Poison  45      49       49       65
# 1                  Ivysaur    Grass  Poison  60      62       63       80
# 2                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 795                Diancie     Rock   Fairy  50     100      150      100
# 796    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 799              Volcanion     Fire   Water  80     110      120      130
#
#      Sp._Def  Speed  Generation  Legendary
# ...

# %%
df.pivot_table(index ="Name", columns = "Legendary")
# Out:
#                         Attack        Defense        Generation          HP  \
# Legendary                False  True    False  True       False True  False
# Name
# Abomasnow                 92.0    NaN    75.0    NaN        4.0   NaN  90.0
# AbomasnowMega Abomasnow  132.0    NaN   105.0    NaN        4.0   NaN  90.0
# Abra                      20.0    NaN    15.0    NaN        1.0   NaN  25.0
# Absol                    130.0    NaN    60.0    NaN        3.0   NaN  65.0
# AbsolMega Absol          150.0    NaN    60.0    NaN        3.0   NaN  65.0
# ...                        ...    ...     ...    ...        ...   ...   ...
# Zoroark                  105.0    NaN    60.0    NaN        5.0   NaN  60.0
# Zorua                     65.0    NaN    40.0    NaN        5.0   NaN  40.0
# Zubat                     45.0    NaN    35.0    NaN        1.0   NaN  40.0
# Zweilous                  85.0    NaN    70.0    NaN        5.0   NaN  72.0
# ...

# %%
pd.crosstab(df.Generation,df.Legendary, margins =True)
# Out:
# Legendary   False  True  All
# Generation
# 1             160     6  166
# 2             101     5  106
# 3             142    18  160
# 4             108    13  121
# 5             150    15  165
# 6              74     8   82
# All           735    65  800

# %%
pd.crosstab(df.Generation,df.Legendary,normalize= "index")
# Out:
# Legendary      False     True
# Generation
# 1           0.963855  0.036145
# 2           0.952830  0.047170
# 3           0.887500  0.112500
# 4           0.892562  0.107438
# 5           0.909091  0.090909
# 6           0.902439  0.097561

# %%
# average HP
import numpy as np
pd.crosstab([df.Generation],[df.Legendary],values =df.HP, aggfunc =np.average).plot(x
# Out:
#   File "<ipython-input-121-412158f4601a>", line 3
#     pd.crosstab([df.Generation],[df.Legendary],values =df.HP, aggfunc =np.average).plot(x
#                                                                                          ^
# SyntaxError: unexpected EOF while parsing

# %%
import seaborn as sns

# %%
df
# Out:
#                       Name   Type_1  Type_2  HP  Attack  Defense  Sp._Atk  \
# 0                Bulbasaur    Grass  Poison  45      49       49       65
# 1                  Ivysaur    Grass  Poison  60      62       63       80
# 2                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 795                Diancie     Rock   Fairy  50     100      150      100
# 796    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 799              Volcanion     Fire   Water  80     110      120      130
#
#      Sp._Def  Speed  Generation  Legendary
# ...

# %%
sns.distplot(df["Attack"], kde = False).set_title("df.attack")
plt.show()

# %%
sns.distplot(df["Defense"], kde = True).set_title("df.defense")
plt.show()

# %%
sns.distplot(df["Attack"], kde = False)
sns.distplot(df["Defense"], kde = False).set_title("Attack vs.defense")
plt.show()

# %%
sns.distplot(df["Attack"], kde = False,)
sns.distplot(df["Defense"], kde = False).set_title("Attack vs.defense")
plt.show()

# %%
sns.boxplot(df['Attack']).set_title('boxplot of attack')
# Out:
# Text(0.5, 1.0, 'boxplot of attack')

# %%
sns.boxplot(df['Defense']).set_title('boxplot of defense')
# Out:
# Text(0.5, 1.0, 'boxplot of defense')

# %%
sns.boxplot(df['Attack'])
sns.boxplot(df['Defense']).set_title('boxplot of attack and defense')
plt.show()

# %%
sns.boxplot(x = df["Attack"], y = df["Legendary"])
