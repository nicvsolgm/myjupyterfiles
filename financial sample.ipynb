# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
fin = pd.read_csv('Financial_Sample.csv')

# %%
fin.head(10)
# Out:
#             Segment  Country     Product   Discount Band   Units Sold  \
# 0        Government   Canada   Carretera            None       1618.5
# 1        Government  Germany   Carretera            None       1321.0
# 2         Midmarket   France   Carretera            None       2178.0
# 3         Midmarket  Germany   Carretera            None        888.0
# 4         Midmarket   Mexico   Carretera            None       2470.0
# 5        Government  Germany   Carretera            None       1513.0
# 6         Midmarket  Germany     Montana            None        921.0
# 7  Channel Partners   Canada     Montana            None       2518.0
# 8        Government   France     Montana            None       1899.0
# 9  Channel Partners  Germany     Montana            None       1545.0
#
#    Manufacturing Price   Sale Price    Gross Sales   Discounts   \
# 0                $3.00       $20.00     $32,370.00        $-
# 1                $3.00       $20.00     $26,420.00        $-
# ...

# %%
fin.head()
# Out:
#       Segment  Country     Product   Discount Band   Units Sold  \
# 0  Government   Canada   Carretera            None       1618.5
# 1  Government  Germany   Carretera            None       1321.0
# 2   Midmarket   France   Carretera            None       2178.0
# 3   Midmarket  Germany   Carretera            None        888.0
# 4   Midmarket   Mexico   Carretera            None       2470.0
#
#    Manufacturing Price   Sale Price   Gross Sales   Discounts         Sales   \
# 0                $3.00       $20.00    $32,370.00        $-      $32,370.00
# 1                $3.00       $20.00    $26,420.00        $-      $26,420.00
# 2                $3.00       $15.00    $32,670.00        $-      $32,670.00
# 3                $3.00       $15.00    $13,320.00        $-      $13,320.00
# 4                $3.00       $15.00    $37,050.00        $-      $37,050.00
#
#           COGS        Profit       Date  Month Number  Month Name   Year
# ...

# %%
fin.rename(columns = {"Month Number": "Month_Number"}, inplace = True)

# %%
fin.head()
# Out:
#       Segment  Country     Product   Discount Band   Units Sold  \
# 0  Government   Canada   Carretera            None       1618.5
# 1  Government  Germany   Carretera            None       1321.0
# 2   Midmarket   France   Carretera            None       2178.0
# 3   Midmarket  Germany   Carretera            None        888.0
# 4   Midmarket   Mexico   Carretera            None       2470.0
#
#    Manufacturing Price   Sale Price   Gross Sales   Discounts         Sales   \
# 0                $3.00       $20.00    $32,370.00        $-      $32,370.00
# 1                $3.00       $20.00    $26,420.00        $-      $26,420.00
# 2                $3.00       $15.00    $32,670.00        $-      $32,670.00
# 3                $3.00       $15.00    $13,320.00        $-      $13,320.00
# 4                $3.00       $15.00    $37,050.00        $-      $37,050.00
#
#           COGS        Profit       Date  Month_Number  Month Name   Year
# ...

# %%
fin.pivot_table(index=['Year','Date','Segment','Month_Number'], columns='Country')
# Out:
#                                                Units Sold               \
# Country                                            Canada       France
# Year Date      Segment          Month_Number
# 2013 10/1/2013 Channel Partners 10            2299.000000  1198.000000
#                Enterprise       10             345.000000   704.000000
#                Government       10            1822.666667  1745.333333
#                Midmarket        10            1743.000000  2167.000000
#                Small Business   10             269.000000  1221.000000
# ...                                                   ...          ...
# 2014 9/1/2014  Channel Partners 9             1445.000000  2671.000000
#                Enterprise       9              567.000000   663.000000
#                Government       9             1056.333333  1651.666667
#                Midmarket        9              218.000000  2620.000000
#                Small Business   9             2134.000000  2151.000000
# ...

# %%
df=fin.loc[["Country","Year","Profit"]]
